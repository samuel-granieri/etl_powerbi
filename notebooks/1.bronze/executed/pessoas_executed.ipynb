# %% [markdown]
# ## Ingestão de dados - pessoas

# %% [markdown]
# #### 1.Criar sessão spark e carregar configurações

# %%
import sys
sys.path.append("/app")

from utils import create_spark_session, load_config, save_table

spark = create_spark_session("pessoas")
config = load_config()

db = config["sqlserver"]
tables = config["tables"]
jdbc_url = f"jdbc:sqlserver://{db['host']}:{db['port']};databaseName={db['database']}"
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/07 03:49:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/07 03:49:38 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).

# %% [markdown]
# #### 2.Executar consulta SQL

# %%
tabela_nome = "pessoas"
query = ""

if tabela_nome in [table["name"] for table in tables]:

    query = f"""
        SELECT * FROM {tabela_nome}
    """

# %% [markdown]
# #### 3.Armazenar dados na camada bronze

# %%
df = spark.read \
     .format("jdbc") \
     .option("url", jdbc_url) \
     .option("query", query) \
     .option("user", db["user"]) \
     .option("password", db["password"]) \
     .option("driver", db["driver"]) \
     .option("encrypt", "true") \
     .option("trustServerCertificate", "true") \
     .load()

table_config = next(
    table for table in tables
    if table["name"] == tabela_nome
)

save_table(
    df=df,
    table_config=table_config,
    config=config,
    spark=spark,
    layer="bronze"
)
# Out:
# Processando tabela: pessoas
# path: data/bronze/pessoas
# modo incremental: MERGE
# usando watermark
# 26/04/07 03:49:49 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 3:>                                                        (0 + 20) / 50]
# [Stage 3:======================>                                 (20 + 24) / 50]
# [Stage 9:>                                                          (0 + 1) / 1]
# ultimo valor de data_atualizado: 2026-04-01 16:43:38.003000
# [Stage 29:>                                                         (0 + 1) / 1]
# merge executado
