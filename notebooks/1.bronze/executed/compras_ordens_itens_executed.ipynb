# %% [markdown]
# ## Ingestão de dados - compras_ordens_itens

# %% [markdown]
# #### 1.Criar sessão spark e carregar configurações

# %%
import sys
sys.path.append("/app")


from utils import create_spark_session, load_config, save_table

spark = create_spark_session("compras_ordens_itens")
config = load_config()

db = config["sqlserver"]
tables = config["tables"]
jdbc_url = f"jdbc:sqlserver://{db['host']}:{db['port']};databaseName={db['database']}"
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/07 03:47:56 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/07 03:47:56 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).

# %% [markdown]
# #### 2.Executar consulta SQL

# %%
tabela_nome = "compras_ordens_itens"
query = ""

if tabela_nome in [table["name"] for table in tables]:

    query = f"""
        SELECT * FROM {tabela_nome}
    """

# %% [markdown]
# #### 3.Armazenar dados na camada bronze

# %%
df = spark.read \
     .format("jdbc") \
     .option("url", jdbc_url) \
     .option("query", query) \
     .option("user", db["user"]) \
     .option("password", db["password"]) \
     .option("driver", db["driver"]) \
     .option("encrypt", "true") \
     .option("trustServerCertificate", "true") \
     .load()

table_config = next(
    table for table in tables
    if table["name"] == tabela_nome
)

save_table(
    df=df,
    table_config=table_config,
    config=config,
    spark=spark,
    layer="bronze"
)
# Out:
# Processando tabela: compras_ordens_itens
# path: data/bronze/compras_ordens_itens
# modo incremental: MERGE
# usando watermark
# 26/04/07 03:48:07 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 3:>                                                        (0 + 20) / 50]
# [Stage 3:=======================>                                (21 + 21) / 50]
# [Stage 9:>                                                          (0 + 1) / 1]
# ultimo valor de data_atualizado: 2026-04-06 18:02:15.010000
# sem novos dados
